# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv')

# %%
df.head()
# Out:
#    Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0  1960   179323175  3384200   288460   3095700    9110          17190
# 1  1961   182992000  3488000   289390   3198600    8740          17220
# 2  1962   185771000  3752200   301510   3450700    8530          17550
# 3  1963   188483000  4109500   316970   3792500    8640          17650
# 4  1964   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800

# %%
df.tail()
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 50  2010   309330219  10363873  1251248   9112625   14772          85593
# 51  2011   311587816  10258774  1206031   9052743   14661          84175
# 52  2012   313873685  10219059  1217067   9001992   14866          85141
# 53  2013   316497531   9850445  1199684   8650761   14319          82109
# 54  2014   318857056   9475816  1197987   8277829   14249          84041
#
#     Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 50   369089              781844   2168457        6204601         739565
# 51   354772              752423   2185140        6151095         716508
# 52   355051              762009   2109932        6168874         723186
# 53   345095              726575   1931835        6018632         700294
# 54   325802              741291   1729806        5858496         689527

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                55 non-null     int64
#  1   Population          55 non-null     int64
#  2   Total               55 non-null     int64
#  3   Violent             55 non-null     int64
#  4   Property            55 non-null     int64
#  5   Murder              55 non-null     int64
#  6   Forcible_Rape       55 non-null     int64
#  7   Robbery             55 non-null     int64
#  8   Aggravated_assault  55 non-null     int64
#  9   Burglary            55 non-null     int64
#  10  Larceny_Theft       55 non-null     int64
#  11  Vehicle_Theft       55 non-null     int64
# dtypes: int64(12)
# memory usage: 5.3 KB

# %%
df.shape[0]
# Out:
# 55

# %%
df.columns
# Out:
# Index(['Year', 'Population', 'Total', 'Violent', 'Property', 'Murder',
#        'Forcible_Rape', 'Robbery', 'Aggravated_assault', 'Burglary',
#        'Larceny_Theft', 'Vehicle_Theft'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=55, step=1)

# %%
c = df.groupby('Year')
c = c.sum()
c = c.sort_values(['Murder'], ascending = False)
c.head(1)
# Out:
#       Population     Total  Violent  Property  Murder  Forcible_Rape  Robbery  \
# Year
# 1991   252177000  14872900  1911770  12961100   24700         106590   687730
#
#       Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# Year
# 1991             1092740   3157200        8142200        1661700

# %%
c = df.groupby('Year').sum()
c = c.sort_values(['Population'], ascending = False)
c.head(1)
# Out:
#       Population    Total  Violent  Property  Murder  Forcible_Rape  Robbery  \
# Year
# 2014   318857056  9475816  1197987   8277829   14249          84041   325802
#
#       Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# Year
# 2014              741291   1729806        5858496         689527

# %%
filtered = df.drop_duplicates(['Year'])
filtered
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 0   1960   179323175   3384200   288460   3095700    9110          17190
# 1   1961   182992000   3488000   289390   3198600    8740          17220
# 2   1962   185771000   3752200   301510   3450700    8530          17550
# 3   1963   188483000   4109500   316970   3792500    8640          17650
# 4   1964   191141000   4564600   364220   4200400    9360          21420
# 5   1965   193526000   4739400   387390   4352000    9960          23410
# 6   1966   195576000   5223500   430180   4793300   11040          25820
# 7   1967   197457000   5903400   499930   5403500   12240          27620
# 8   1968   199399000   6720200   595010   6125200   13800          31670
# 9   1969   201385000   7410900   661870   6749000   14760          37170
# 10  1970   203235298   8098000   738820   7359200   16000          37990
# 11  1971   206212000   8588200   816500   7771700   17780          42260
# ...

# %%
one_prod = filtered[filtered.Year == 2014]
one_prod
# Out:
#     Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 54  2014   318857056  9475816  1197987   8277829   14249          84041
#
#     Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 54   325802              741291   1729806        5858496         689527

# %%
df.groupby('Year').Violent.mean()
# Out:
# Year
# 1960     288460
# 1961     289390
# 1962     301510
# 1963     316970
# 1964     364220
# 1965     387390
# 1966     430180
# 1967     499930
# 1968     595010
# 1969     661870
# 1970     738820
# 1971     816500
# 1972     834900
# 1973     875910
# 1974     974720
# 1975    1039710
# 1976    1004210
# 1977    1029580
# 1978    1085550
# 1979    1208030
# 1980    1344520
# 1981    1361820
# 1982    1322390
# 1983    1258090
# 1984    1273280
# 1985    1328800
# 1986    1489169
# 1987    1483999
# 1988    1566220
# 1989    1646040
# 1990    1820130
# 1991    1911770
# 1992    1932270
# 1993    1926020
# 1994    1857670
# 1995    1798790
# 1996    1688540
# 1997    1634770
# 1998    1531044
# 1999    1426044
# 2000    1425486
# 2001    1439480
# 2002    1423677
# 2003    1383676
# 2004    1360088
# 2005    1390745
# 2006    1418043
# 2007    1408337
# 2008    1392628
# 2009    1325896
# 2010    1251248
# 2011    1206031
# 2012    1217067
# 2013    1199684
# 2014    1197987
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Population', 'Total', 'Violent', 'Property', 'Murder',
#        'Forcible_Rape', 'Robbery', 'Aggravated_assault', 'Burglary',
#        'Larceny_Theft', 'Vehicle_Theft'],
#       dtype='object')

# %%
df.groupby('Year').Property.describe()
# Out:
#       count        mean  std         min         25%         50%         75%  \
# Year
# 1960    1.0   3095700.0  NaN   3095700.0   3095700.0   3095700.0   3095700.0
# 1961    1.0   3198600.0  NaN   3198600.0   3198600.0   3198600.0   3198600.0
# 1962    1.0   3450700.0  NaN   3450700.0   3450700.0   3450700.0   3450700.0
# 1963    1.0   3792500.0  NaN   3792500.0   3792500.0   3792500.0   3792500.0
# 1964    1.0   4200400.0  NaN   4200400.0   4200400.0   4200400.0   4200400.0
# 1965    1.0   4352000.0  NaN   4352000.0   4352000.0   4352000.0   4352000.0
# 1966    1.0   4793300.0  NaN   4793300.0   4793300.0   4793300.0   4793300.0
# 1967    1.0   5403500.0  NaN   5403500.0   5403500.0   5403500.0   5403500.0
# 1968    1.0   6125200.0  NaN   6125200.0   6125200.0   6125200.0   6125200.0
# 1969    1.0   6749000.0  NaN   6749000.0   6749000.0   6749000.0   6749000.0
# 1970    1.0   7359200.0  NaN   7359200.0   7359200.0   7359200.0   7359200.0
# ...

# %%
df.iloc[:3]
# Out:
#    Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0  1960   179323175  3384200   288460   3095700    9110          17190
# 1  1961   182992000  3488000   289390   3198600    8740          17220
# 2  1962   185771000  3752200   301510   3450700    8530          17550
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800

# %%
df.loc[:,['Year', 'Population', 'Total', 'Violent']].head()
# Out:
#    Year  Population    Total  Violent
# 0  1960   179323175  3384200   288460
# 1  1961   182992000  3488000   289390
# 2  1962   185771000  3752200   301510
# 3  1963   188483000  4109500   316970
# 4  1964   191141000  4564600   364220

# %%
df[['Year', 'Population']].head()
# Out:
#    Year  Population
# 0  1960   179323175
# 1  1961   182992000
# 2  1962   185771000
# 3  1963   188483000
# 4  1964   191141000

# %%
df.loc[df.index[[2,3]],['Year', 'Population']]
# Out:
#    Year  Population
# 2  1962   185771000
# 3  1963   188483000

# %%
df[df['Year']>2000]
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 41  2001   285317559  11876669  1439480  10437480   16037          90863
# 42  2002   287973924  11878954  1423677  10455277   16229          95235
# 43  2003   290690788  11826538  1383676  10442862   16528          93883
# 44  2004   293656842  11679474  1360088  10319386   16148          95089
# 45  2005   296507061  11565499  1390745  10174754   16740          94347
# 46  2006   299398484  11401511  1418043   9983568   17030          92757
# 47  2007   301621157  11251828  1408337   9843481   16929          90427
# 48  2008   304374846  11160543  1392628   9767915   16442          90479
# 49  2009   307006550  10762956  1325896   9337060   15399          89241
# 50  2010   309330219  10363873  1251248   9112625   14772          85593
# 51  2011   311587816  10258774  1206031   9052743   14661          84175
# 52  2012   313873685  10219059  1217067   9001992   14866          85141
# ...

# %%
df[df['Year'].between(2000, 2010)]
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 40  2000   281421906  11608072  1425486  10182586   15586          90178
# 41  2001   285317559  11876669  1439480  10437480   16037          90863
# 42  2002   287973924  11878954  1423677  10455277   16229          95235
# 43  2003   290690788  11826538  1383676  10442862   16528          93883
# 44  2004   293656842  11679474  1360088  10319386   16148          95089
# 45  2005   296507061  11565499  1390745  10174754   16740          94347
# 46  2006   299398484  11401511  1418043   9983568   17030          92757
# 47  2007   301621157  11251828  1408337   9843481   16929          90427
# 48  2008   304374846  11160543  1392628   9767915   16442          90479
# 49  2009   307006550  10762956  1325896   9337060   15399          89241
# 50  2010   309330219  10363873  1251248   9112625   14772          85593
#
#     Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# ...

# %%
df.groupby('Year')['Robbery'].mean()
# Out:
# Year
# 1960    107840
# 1961    106670
# 1962    110860
# 1963    116470
# 1964    130390
# 1965    138690
# 1966    157990
# 1967    202910
# 1968    262840
# 1969    298850
# 1970    349860
# 1971    387700
# 1972    376290
# 1973    384220
# 1974    442400
# 1975    470500
# 1976    427810
# 1977    412610
# 1978    426930
# 1979    480700
# 1980    565840
# 1981    592910
# 1982    553130
# 1983    506570
# 1984    485010
# 1985    497870
# 1986    542775
# 1987    517704
# 1988    542970
# 1989    578330
# 1990    639270
# 1991    687730
# 1992    672480
# 1993    659870
# 1994    618950
# 1995    580510
# 1996    535590
# 1997    498534
# 1998    446625
# 1999    409371
# 2000    408016
# 2001    423557
# 2002    420806
# 2003    414235
# 2004    401470
# 2005    417438
# 2006    447403
# 2007    445125
# 2008    443574
# 2009    408742
# 2010    369089
# 2011    354772
# 2012    355051
# 2013    345095
# 2014    325802
# Name: Robbery, dtype: int64

# %%
df.sort_values(by=['Burglary', 'Larceny_Theft'], ascending=[False, True])
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 20  1980   225349264  13408300  1344520  12063700   23040          82990
# 21  1981   229146000  13423800  1361820  12061900   22520          82500
# 22  1982   231534000  12974400  1322390  11652000   21010          78770
# 19  1979   220099000  12249500  1208030  11041500   21460          76390
# 15  1975   213124000  11292400  1039710  10252700   20510          56090
# 26  1986   240132887  13211869  1489169  11722700   20613          91459
# 27  1987   242282918  13508700  1483999  12024700   20096          91110
# 28  1988   245807000  13923100  1566220  12356900   20680          92490
# 29  1989   248239000  14251400  1646040  12605400   21500          94500
# 31  1991   252177000  14872900  1911770  12961100   24700         106590
# 23  1983   233981000  12108600  1258090  10850500   19310          78920
# 18  1978   218059000  11209000  1085550  10123400   19560          67610
# ...

# %%
df.pivot_table(index='Year', columns='Population', values='Violent', aggfunc='mean')
# Out:
# Population  179323175  182992000  185771000  188483000  191141000  193526000  \
# Year
# 1960         288460.0        NaN        NaN        NaN        NaN        NaN
# 1961              NaN   289390.0        NaN        NaN        NaN        NaN
# 1962              NaN        NaN   301510.0        NaN        NaN        NaN
# 1963              NaN        NaN        NaN   316970.0        NaN        NaN
# 1964              NaN        NaN        NaN        NaN   364220.0        NaN
# 1965              NaN        NaN        NaN        NaN        NaN   387390.0
# 1966              NaN        NaN        NaN        NaN        NaN        NaN
# 1967              NaN        NaN        NaN        NaN        NaN        NaN
# 1968              NaN        NaN        NaN        NaN        NaN        NaN
# 1969              NaN        NaN        NaN        NaN        NaN        NaN
# 1970              NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %% [markdown]
# # New operations

# %%
df['Year'].unique()
# Out:
# array([1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970,
#        1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981,
#        1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992,
#        1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#        2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014],
#       dtype=int64)

# %%
df.describe().T
# Out:
#                     count          mean           std          min  \
# Year                 55.0  1.987000e+03  1.602082e+01       1960.0
# Population           55.0  2.461556e+08  4.166216e+07  179323175.0
# Total                55.0  1.060315e+07  3.175931e+06    3384200.0
# Violent              55.0  1.188806e+06  4.597107e+05     288460.0
# Property             55.0  9.412499e+06  2.738512e+06    3095700.0
# Murder               55.0  1.731724e+04  4.267443e+03       8530.0
# Forcible_Rape        55.0  7.271480e+04  2.827801e+04      17190.0
# Robbery              55.0  4.164499e+05  1.505064e+05     106670.0
# Aggravated_assault   55.0  6.811818e+05  2.960255e+05     154320.0
# Burglary             55.0  2.424017e+06  7.259004e+05     912100.0
# Larceny_Theft        55.0  5.959947e+06  1.846401e+06    1855400.0
# Vehicle_Theft        55.0  1.028614e+06  3.455693e+05     328200.0
#
#                             25%          50%          75%          max
# ...

# %%
df.corr()
# Out:
#                         Year  Population     Total   Violent  Property  \
# Year                1.000000    0.996553  0.597025  0.715312  0.571376
# Population          0.996553    1.000000  0.536348  0.662794  0.509765
# Total               0.597025    0.536348  1.000000  0.958353  0.998809
# Violent             0.715312    0.662794  0.958353  1.000000  0.943351
# Property            0.571376    0.509765  0.998809  0.943351  1.000000
# Murder              0.256010    0.188833  0.887144  0.795300  0.895641
# Forcible_Rape       0.825216    0.782429  0.928156  0.973914  0.912517
# Robbery             0.451001    0.387308  0.965439  0.919249  0.965363
# Aggravated_assault  0.792431    0.748054  0.897225  0.981071  0.875536
# Burglary            0.157445    0.092560  0.823891  0.646607  0.847149
# Larceny_Theft       0.703818    0.649060  0.986707  0.974791  0.980528
# Vehicle_Theft       0.436975    0.377624  0.912546  0.909182  0.906130
#
# ...

# %%
def Var_Summary(x):
    return pd.Series([x.count(), x.isnull().sum(), x.sum(), x.mean(), x.median(), x.var(), x.std(), 
                      x.min(),x.quantile(0.01), x.quantile(0.05), x.quantile(0.10),x.quantile(0.25), 
                      x.quantile(0.50), x.quantile(0.75), x.quantile(0.90), 
                      x.quantile(0.99), x.max()],
                      index=['Count','Missing Values', 'Sum','Mean','Median', 'VAR', 'STD', 'MIN','P1','P5','P10',
                             'P25','P50','P75','P90','P99','Max'])

# %%
Var_Summary(df).T
# Out:
# Count             Year                  55
# Population           ...
# Missing Values    Year                  0
# Population            ...
# Sum               Year                       109285
# Population  ...
# Mean              Year                  1.987000e+03
# Population ...
# Median            Year                       1987.0
# Population  ...
# VAR               Year                  2.566667e+02
# Population ...
# STD               Year                  1.602082e+01
# Population ...
# MIN               Year                       1960
# Population    ...
# P1                Year                  1.960540e+03
# Population ...
# P5                Year                       1962.7
# Population  ...
# P10               Year                       1965.4
# Population  ...
# P25               Year                       1973.5
# Population  ...
# P50               Year                       1987.0
# Population  ...
# P75               Year                       2000.5
# ...

# %%
df.isna().sum()
# Out:
# Year                  0
# Population            0
# Total                 0
# Violent               0
# Property              0
# Murder                0
# Forcible_Rape         0
# Robbery               0
# Aggravated_assault    0
# Burglary              0
# Larceny_Theft         0
# Vehicle_Theft         0
# dtype: int64

# %%
import pandas_profiling
pandas_profiling.ProfileReport(df)

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.scatter(df['Year'], df['Population'])
plt.show()
